# %% [markdown]
# # Introduction to Causality
#
# Causality is ...  $P(Y | do(X))$

# %%
import numpy as np
from matplotlib import pyplot as plt


n = 1000
y = np.random.randn( n, 1 )
plt.hist(y, bins=20)
# Out:
# (array([  1.,   4.,   7.,  11.,  19.,  45.,  56.,  75., 121., 104., 132.,
#         120., 108.,  81.,  49.,  29.,  22.,  10.,   3.,   3.]),
#  array([-3.40336598, -3.07587248, -2.74837897, -2.42088547, -2.09339196,
#         -1.76589846, -1.43840495, -1.11091145, -0.78341794, -0.45592444,
#         -0.12843093,  0.19906257,  0.52655608,  0.85404958,  1.18154309,
#          1.50903659,  1.8365301 ,  2.1640236 ,  2.49151711,  2.81901061,
#          3.14650412]),
#  <BarContainer object of 20 artists>)
