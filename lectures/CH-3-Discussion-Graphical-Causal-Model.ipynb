# %% [markdown]
# ### Drawing causal graphs
#
# Consider the following variables sets. Draw a causal graph between the variables.
#
# - Sea level (A), Global temperature (B), Extreme weather condition (C)
#
# - Stress (A), Depression (B), Insomnia (C)
#
# - Distance (A), Ticket Price (B), Flight Passengers (C)
#
# - Deforestation (A), Fossil fuel consumption (B), Global temperature (C)

# %%
import graphviz as gr
g = gr.Digraph()
g.node("A", label="Sea level")
g.node("B", label="Global temperature")
g.node("C", label="Extreme weather condition")
g

# %%
g = gr.Digraph()
g.node("A", label="Stress")
g.node("B", label="Depression")
g.node("C", label="Insomnia")
g

# %%
g = gr.Digraph()
g.node("A", label="Distance")
g.node("B", label="Ticket price")
g.node("C", label="Flight Passengers")
g

# %%
g = gr.Digraph()
g.node("A", label="Deforestation")
g.node("B", label="Fossil fuel consumption")
g.node("C", label="Global temperature")
g

# %% [markdown]
# ### Another example of d-separation

# %%
g = gr.Digraph()
g.edge("C", "A")
g.edge("C", "B")
g.edge("D", "A")
g.edge("B", "E")
g.edge("F", "E")
g.edge("A", "G")

g

# %% [markdown]
# 1. $D \perp C$. It contains a collider that it has **not** been conditioned on.
# 2. $D \not\perp C| A $. It contains a collider that it has  been conditioned on.
# 3. $D \not\perp C| G $. It contains the descendent of a collider that has  been conditioned on. You can see G as some kind of proxy for A here.
# 4. $A \perp F $. It contains a collider, B->E<-F, that it has **not** been conditioned on.
# 5. $A \not\perp F|E $. It contains a collider, B->E<-F, that it has been conditioned on.
# 6. $A \perp F|E, C $. It contains a collider, B->E<-F, that it has been conditioned on, but it contains a non collider that has been conditioned on. Conditioning on E opens the path, but conditioning on C closes it again.

# %% [markdown]
# ### Automatic evaluation of d-separation
#
# We can use the *networkx* library to test for conditional independence in probability distributions that can be factorized using DAGs.

# %%
import networkx as nx

G = nx.DiGraph()
G.add_edges_from(
    [
        ("D", "A"),
        ("A", "G"),
        ("C", "A"),
        ("C", "B"),
        ("B", "E"),
        ("F", "E"),
    ]
)
nx.draw(G, with_labels=True)
# Out:
# True

# %%
#Is D and C d-separated given A? 
nx.d_separated(G, {"D"}, {"C"}, {"A"})
# Out:
# False

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e9f789e8-0475-4790-a085-15ec7f70f6c3' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
