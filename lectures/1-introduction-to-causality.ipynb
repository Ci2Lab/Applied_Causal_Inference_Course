# %% [markdown]
# # Introduction to Causality
#
# Causality is ...  $P(Y | do(X))$

# %%
import numpy as np
from matplotlib import pyplot as plt


n = 1000
y = np.random.randn( n, 1 )
plt.hist(y, bins=20)
# Out:
# (array([  1.,   2.,   6.,  13.,  17.,  52.,  42.,  72.,  96., 103., 132.,
#         119., 106.,  91.,  45.,  43.,  30.,  18.,  11.,   1.]),
#  array([-3.24793088, -2.94372992, -2.63952896, -2.33532801, -2.03112705,
#         -1.7269261 , -1.42272514, -1.11852418, -0.81432323, -0.51012227,
#         -0.20592132,  0.09827964,  0.4024806 ,  0.70668155,  1.01088251,
#          1.31508347,  1.61928442,  1.92348538,  2.22768633,  2.53188729,
#          2.83608825]),
#  <BarContainer object of 20 artists>)
