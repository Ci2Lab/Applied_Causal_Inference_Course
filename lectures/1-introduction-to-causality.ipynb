# %% [markdown]
# # Introduction to Causality
#
# Causality is ...  $P(Y | do(X))$

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_theme()
n = 1000
y = np.random.randn( n, 1 )
plt.hist(y, bins=20)
plt.show()
